# %% [markdown]
# # Pandas reference
# https://learning.oreilly.com/library/view/python-for-data/9781449323592/ch05.html

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# %config IPCompleter.greedy=True

# %%
# Series is indexed ndarray.
a = pd.Series([1,1,2,3,5,8], index=['a','b','c','d','e','f'])
a.name = 'fib'
a.index.name = 'ind'
a
# Out:
# ind
# a    1
# b    1
# c    2
# d    3
# e    5
# f    8
# Name: fib, dtype: int64

# %%
a[a>3]
# Out:
# ind
# e    5
# f    8
# Name: fib, dtype: int64

# %%
a[['a','b']]
# Out:
# ind
# a    1
# b    1
# Name: fib, dtype: int64

# %%
a.isnull()
# Out:
# ind
# a    False
# b    False
# c    False
# d    False
# e    False
# f    False
# Name: fib, dtype: bool

# %%
a.index = np.arange(6) # reassign index.

# %%
a
# Out:
# 0    1
# 1    1
# 2    2
# 3    3
# 4    5
# 5    8
# Name: fib, dtype: int64

# %%
df1 = pd.read_csv('/Users/nram/Jupyter/Data/CSV/pers-health-data-feb2021.csv')
df1.head(10)
# Out:
#             Timestamp       Date        Time  Who      What       Value
# 0  2/21/2021 21:00:18  2/20/2021  4:30:00 PM  Ram      Temp       100.4
# 1  2/21/2021 21:00:48  2/20/2021  9:00:00 AM  Sri      Temp       100.4
# 2  2/21/2021 21:01:37  2/21/2021  8:30:00 AM  Ram      Temp       101.8
# 3  2/21/2021 21:02:15  2/21/2021  9:30:00 AM  Sri      Temp       100.8
# 4  2/21/2021 21:03:13  2/21/2021  9:00:00 AM  Ram      SP02          93
# 5  2/21/2021 21:05:41  2/21/2021  4:00:00 PM  Sri      SP02          99
# 6  2/21/2021 21:06:24  2/21/2021  4:00:00 PM  Lia      SP02          99
# 7  2/21/2021 21:06:59  2/21/2021  8:30:00 AM  Ram  Medicine     Tylenol
# 8  2/21/2021 21:07:29  2/21/2021  4:00:00 PM  Ram  Medicine     Tylenol
# 9  2/21/2021 21:08:03  2/21/2021  4:00:00 PM  Ram  Medicine  Robitussin

# %%
df1['Who'].unique()
# Out:
# array(['Ram', 'Sri', 'Lia', 'Krithi'], dtype=object)

# %%
df2=df1[df1['What'].isin(['Temp', 'SP02'])]
df2
# Out:
#              Timestamp       Date         Time     Who  What  Value
# 0   2/21/2021 21:00:18  2/20/2021   4:30:00 PM     Ram  Temp  100.4
# 1   2/21/2021 21:00:48  2/20/2021   9:00:00 AM     Sri  Temp  100.4
# 2   2/21/2021 21:01:37  2/21/2021   8:30:00 AM     Ram  Temp  101.8
# 3   2/21/2021 21:02:15  2/21/2021   9:30:00 AM     Sri  Temp  100.8
# 4   2/21/2021 21:03:13  2/21/2021   9:00:00 AM     Ram  SP02     93
# 5   2/21/2021 21:05:41  2/21/2021   4:00:00 PM     Sri  SP02     99
# 6   2/21/2021 21:06:24  2/21/2021   4:00:00 PM     Lia  SP02     99
# 11  2/21/2021 21:21:31  2/21/2021   8:20:00 PM     Ram  Temp   99.2
# 12  2/21/2021 21:22:42  2/21/2021   8:20:00 PM     Ram  SP02     98
# 13   2/22/2021 3:18:30  2/22/2021   2:15:00 AM     Ram  Temp  100.1
# 14   2/22/2021 3:18:57  2/22/2021   2:15:00 AM     Ram  SP02     94
# 15   2/22/2021 3:28:56  2/22/2021   2:30:00 AM  Krithi  Temp   99.4
# 18  2/22/2021 12:33:31  2/22/2021  11:30:00 AM     Ram  SP02     97

# %%
df2['Value'] = df2['Value'].astype(float)
df2.dtypes
df2
# Out:
# <ipython-input-190-427b7d4de7af>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Value'] = df2['Value'].astype(float)
#              Timestamp       Date         Time     Who  What  Value
# 0   2/21/2021 21:00:18  2/20/2021   4:30:00 PM     Ram  Temp  100.4
# 1   2/21/2021 21:00:48  2/20/2021   9:00:00 AM     Sri  Temp  100.4
# 2   2/21/2021 21:01:37  2/21/2021   8:30:00 AM     Ram  Temp  101.8
# 3   2/21/2021 21:02:15  2/21/2021   9:30:00 AM     Sri  Temp  100.8
# 4   2/21/2021 21:03:13  2/21/2021   9:00:00 AM     Ram  SP02   93.0
# 5   2/21/2021 21:05:41  2/21/2021   4:00:00 PM     Sri  SP02   99.0
# 6   2/21/2021 21:06:24  2/21/2021   4:00:00 PM     Lia  SP02   99.0
# 11  2/21/2021 21:21:31  2/21/2021   8:20:00 PM     Ram  Temp   99.2
# 12  2/21/2021 21:22:42  2/21/2021   8:20:00 PM     Ram  SP02   98.0
# 13   2/22/2021 3:18:30  2/22/2021   2:15:00 AM     Ram  Temp  100.1
# 14   2/22/2021 3:18:57  2/22/2021   2:15:00 AM     Ram  SP02   94.0
# 15   2/22/2021 3:28:56  2/22/2021   2:30:00 AM  Krithi  Temp   99.4
# 18  2/22/2021 12:33:31  2/22/2021  11:30:00 AM     Ram  SP02   97.0

# %%
df1.values
# Out:
# array([['2/21/2021 21:00:18', '2/20/2021', '4:30:00 PM', 'Ram', 'Temp',
#         '100.4'],
#        ['2/21/2021 21:00:48', '2/20/2021', '9:00:00 AM', 'Sri', 'Temp',
#         '100.4'],
#        ['2/21/2021 21:01:37', '2/21/2021', '8:30:00 AM', 'Ram', 'Temp',
#         '101.8'],
#        ['2/21/2021 21:02:15', '2/21/2021', '9:30:00 AM', 'Sri', 'Temp',
#         '100.8'],
#        ['2/21/2021 21:03:13', '2/21/2021', '9:00:00 AM', 'Ram', 'SP02',
#         '93'],
#        ['2/21/2021 21:05:41', '2/21/2021', '4:00:00 PM', 'Sri', 'SP02',
#         '99'],
#        ['2/21/2021 21:06:24', '2/21/2021', '4:00:00 PM', 'Lia', 'SP02',
#         '99'],
#        ['2/21/2021 21:06:59', '2/21/2021', '8:30:00 AM', 'Ram',
#         'Medicine', 'Tylenol'],
#        ['2/21/2021 21:07:29', '2/21/2021', '4:00:00 PM', 'Ram',
#         'Medicine', 'Tylenol'],
#        ['2/21/2021 21:08:03', '2/21/2021', '4:00:00 PM', 'Ram',
#         'Medicine', 'Robitussin'],
#        ['2/21/2021 21:08:47', '2/21/2021', '5:00:00 PM', 'Sri',
#         'Medicine', 'Robitussin'],
#        ['2/21/2021 21:21:31', '2/21/2021', '8:20:00 PM', 'Ram', 'Temp',
#         '99.2'],
#        ['2/21/2021 21:22:42', '2/21/2021', '8:20:00 PM', 'Ram', 'SP02',
#         '98'],
#        ['2/22/2021 3:18:30', '2/22/2021', '2:15:00 AM', 'Ram', 'Temp',
#         '100.1'],
#        ['2/22/2021 3:18:57', '2/22/2021', '2:15:00 AM', 'Ram', 'SP02',
#         '94'],
#        ['2/22/2021 3:28:56', '2/22/2021', '2:30:00 AM', 'Krithi', 'Temp',
#         '99.4'],
#        ['2/22/2021 3:29:30', '2/22/2021', '2:30:00 AM', 'Krithi',
#         'Medicine', 'Tylenol'],
#        ['2/22/2021 12:33:09', '2/22/2021', '2:30:00 AM', 'Krithi',
#         'Medicine', 'Tylenol'],
#        ['2/22/2021 12:33:31', '2/22/2021', '11:30:00 AM', 'Ram', 'SP02',
#         '97']], dtype=object)

# %%
#df2['high'] = df2['Value'] > 100
#df2
#df2 = df2.drop(['high', 'High-fever', 'Grade'], axis=1)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 0 to 18
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  13 non-null     object
#  1   Date       13 non-null     object
#  2   Time       13 non-null     object
#  3   Who        13 non-null     object
#  4   What       13 non-null     object
#  5   Value      13 non-null     float64
# dtypes: float64(1), object(5)
# memory usage: 728.0+ bytes

# %%
df2['Grade'] = [ 'High' if x else 'Low' for x in df2['Value'] > 100 ]
df2
# this applies grade to all values - no good.
# Out:
# <ipython-input-193-31a34437d7d5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Grade'] = [ 'High' if x else 'Low' for x in df2['Value'] > 100 ]
#              Timestamp       Date         Time     Who  What  Value Grade
# 0   2/21/2021 21:00:18  2/20/2021   4:30:00 PM     Ram  Temp  100.4  High
# 1   2/21/2021 21:00:48  2/20/2021   9:00:00 AM     Sri  Temp  100.4  High
# 2   2/21/2021 21:01:37  2/21/2021   8:30:00 AM     Ram  Temp  101.8  High
# 3   2/21/2021 21:02:15  2/21/2021   9:30:00 AM     Sri  Temp  100.8  High
# 4   2/21/2021 21:03:13  2/21/2021   9:00:00 AM     Ram  SP02   93.0   Low
# 5   2/21/2021 21:05:41  2/21/2021   4:00:00 PM     Sri  SP02   99.0   Low
# 6   2/21/2021 21:06:24  2/21/2021   4:00:00 PM     Lia  SP02   99.0   Low
# 11  2/21/2021 21:21:31  2/21/2021   8:20:00 PM     Ram  Temp   99.2   Low
# 12  2/21/2021 21:22:42  2/21/2021   8:20:00 PM     Ram  SP02   98.0   Low
# 13   2/22/2021 3:18:30  2/22/2021   2:15:00 AM     Ram  Temp  100.1  High
# 14   2/22/2021 3:18:57  2/22/2021   2:15:00 AM     Ram  SP02   94.0   Low
# 15   2/22/2021 3:28:56  2/22/2021   2:30:00 AM  Krithi  Temp   99.4   Low
# 18  2/22/2021 12:33:31  2/22/2021  11:30:00 AM     Ram  SP02   97.0   Low

# %%
df2[df2['Who'] == 'Ram'].describe()
# Out:
#             Value
# count    8.000000
# mean    97.937500
# std      3.117205
# min     93.000000
# 25%     96.250000
# 50%     98.600000
# 75%    100.175000
# max    101.800000

# %%
df1[['Who']].value_counts()
# Out:
# Who
# Ram       11
# Sri        4
# Krithi     3
# Lia        1
# dtype: int64

# %%
df2.groupby('Who')['Value'].mean()
# Out:
# Who
# Krithi     99.400000
# Lia        99.000000
# Ram        97.937500
# Sri       100.066667
# Name: Value, dtype: float64

# %%
df2['Value'].nlargest(3)
# Out:
# 2    101.8
# 3    100.8
# 0    100.4
# Name: Value, dtype: float64

# %%
df2['Temp_C'] = df2[df2['What']=='Temp'].Value.apply(lambda x: (x-32)*(5/9) )
df2
# Out:
# <ipython-input-198-79359182e067>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Temp_C'] = df2[df2['What']=='Temp'].Value.apply(lambda x: (x-32)*(5/9) )
#              Timestamp       Date         Time     Who  What  Value Grade  \
# 0   2/21/2021 21:00:18  2/20/2021   4:30:00 PM     Ram  Temp  100.4  High
# 1   2/21/2021 21:00:48  2/20/2021   9:00:00 AM     Sri  Temp  100.4  High
# 2   2/21/2021 21:01:37  2/21/2021   8:30:00 AM     Ram  Temp  101.8  High
# 3   2/21/2021 21:02:15  2/21/2021   9:30:00 AM     Sri  Temp  100.8  High
# 4   2/21/2021 21:03:13  2/21/2021   9:00:00 AM     Ram  SP02   93.0   Low
# 5   2/21/2021 21:05:41  2/21/2021   4:00:00 PM     Sri  SP02   99.0   Low
# 6   2/21/2021 21:06:24  2/21/2021   4:00:00 PM     Lia  SP02   99.0   Low
# 11  2/21/2021 21:21:31  2/21/2021   8:20:00 PM     Ram  Temp   99.2   Low
# 12  2/21/2021 21:22:42  2/21/2021   8:20:00 PM     Ram  SP02   98.0   Low
# 13   2/22/2021 3:18:30  2/22/2021   2:15:00 AM     Ram  Temp  100.1  High
# 14   2/22/2021 3:18:57  2/22/2021   2:15:00 AM     Ram  SP02   94.0   Low
# 15   2/22/2021 3:28:56  2/22/2021   2:30:00 AM  Krithi  Temp   99.4   Low
# 18  2/22/2021 12:33:31  2/22/2021  11:30:00 AM     Ram  SP02   97.0   Low
#
#        Temp_C
# 0   38.000000
# 1   38.000000
# 2   38.777778
# 3   38.222222
# 4         NaN
# 5         NaN
# 6         NaN
# 11  37.333333
# 12        NaN
# 13  37.833333
# 14        NaN
# 15  37.444444
# 18        NaN

# %%
df2
# Out:
#              Timestamp       Date         Time     Who  What  Value Grade  \
# 0   2/21/2021 21:00:18  2/20/2021   4:30:00 PM     Ram  Temp  100.4  High
# 1   2/21/2021 21:00:48  2/20/2021   9:00:00 AM     Sri  Temp  100.4  High
# 2   2/21/2021 21:01:37  2/21/2021   8:30:00 AM     Ram  Temp  101.8  High
# 3   2/21/2021 21:02:15  2/21/2021   9:30:00 AM     Sri  Temp  100.8  High
# 4   2/21/2021 21:03:13  2/21/2021   9:00:00 AM     Ram  SP02   93.0   Low
# 5   2/21/2021 21:05:41  2/21/2021   4:00:00 PM     Sri  SP02   99.0   Low
# 6   2/21/2021 21:06:24  2/21/2021   4:00:00 PM     Lia  SP02   99.0   Low
# 11  2/21/2021 21:21:31  2/21/2021   8:20:00 PM     Ram  Temp   99.2   Low
# 12  2/21/2021 21:22:42  2/21/2021   8:20:00 PM     Ram  SP02   98.0   Low
# 13   2/22/2021 3:18:30  2/22/2021   2:15:00 AM     Ram  Temp  100.1  High
# 14   2/22/2021 3:18:57  2/22/2021   2:15:00 AM     Ram  SP02   94.0   Low
# 15   2/22/2021 3:28:56  2/22/2021   2:30:00 AM  Krithi  Temp   99.4   Low
# 18  2/22/2021 12:33:31  2/22/2021  11:30:00 AM     Ram  SP02   97.0   Low
#
#        Temp_C
# 0   38.000000
# 1   38.000000
# 2   38.777778
# 3   38.222222
# 4         NaN
# 5         NaN
# 6         NaN
# 11  37.333333
# 12        NaN
# 13  37.833333
# 14        NaN
# 15  37.444444
# 18        NaN

# %%
def canonicalize (X):
    # 1. sort columns by name = but why ?
    v = sorted(X.columns)
    Y = X[v].copy()
    
    # 2. rows are lexographically sorted
    Y.sort_values(by=v, inplace=True)
    
    # 3. sort row -- Isn't 2 and 3 conflicing? 
    Y.set_index([list(range(0, len(Y)))], inplace=True)
    return Y

df3 = canonicalize(df1)
df3
# Out:
#          Date         Time           Timestamp       Value      What     Who
# 0   2/20/2021   4:30:00 PM  2/21/2021 21:00:18       100.4      Temp     Ram
# 1   2/20/2021   9:00:00 AM  2/21/2021 21:00:48       100.4      Temp     Sri
# 2   2/21/2021   4:00:00 PM  2/21/2021 21:05:41          99      SP02     Sri
# 3   2/21/2021   4:00:00 PM  2/21/2021 21:06:24          99      SP02     Lia
# 4   2/21/2021   4:00:00 PM  2/21/2021 21:07:29     Tylenol  Medicine     Ram
# 5   2/21/2021   4:00:00 PM  2/21/2021 21:08:03  Robitussin  Medicine     Ram
# 6   2/21/2021   5:00:00 PM  2/21/2021 21:08:47  Robitussin  Medicine     Sri
# 7   2/21/2021   8:20:00 PM  2/21/2021 21:21:31        99.2      Temp     Ram
# 8   2/21/2021   8:20:00 PM  2/21/2021 21:22:42          98      SP02     Ram
# 9   2/21/2021   8:30:00 AM  2/21/2021 21:01:37       101.8      Temp     Ram
# 10  2/21/2021   8:30:00 AM  2/21/2021 21:06:59     Tylenol  Medicine     Ram
# 11  2/21/2021   9:00:00 AM  2/21/2021 21:03:13          93      SP02     Ram
# 12  2/21/2021   9:30:00 AM  2/21/2021 21:02:15       100.8      Temp     Sri
# 13  2/22/2021  11:30:00 AM  2/22/2021 12:33:31          97      SP02     Ram
# 14  2/22/2021   2:15:00 AM   2/22/2021 3:18:30       100.1      Temp     Ram
# 15  2/22/2021   2:15:00 AM   2/22/2021 3:18:57          94      SP02     Ram
# 16  2/22/2021   2:30:00 AM  2/22/2021 12:33:09     Tylenol  Medicine  Krithi
# 17  2/22/2021   2:30:00 AM   2/22/2021 3:28:56        99.4      Temp  Krithi
# 18  2/22/2021   2:30:00 AM   2/22/2021 3:29:30     Tylenol  Medicine  Krithi

# %%
# from long to wide format
# how to get Who as well in this ?? -- see below.
df3.pivot(index=['Timestamp','Date','Time','Who'],columns=['What'], values='Value')
# Out:
# What                                               Medicine SP02   Temp
# Timestamp          Date      Time        Who
# 2/21/2021 21:00:18 2/20/2021 4:30:00 PM  Ram            NaN  NaN  100.4
# 2/21/2021 21:00:48 2/20/2021 9:00:00 AM  Sri            NaN  NaN  100.4
# 2/21/2021 21:01:37 2/21/2021 8:30:00 AM  Ram            NaN  NaN  101.8
# 2/21/2021 21:02:15 2/21/2021 9:30:00 AM  Sri            NaN  NaN  100.8
# 2/21/2021 21:03:13 2/21/2021 9:00:00 AM  Ram            NaN   93    NaN
# 2/21/2021 21:05:41 2/21/2021 4:00:00 PM  Sri            NaN   99    NaN
# 2/21/2021 21:06:24 2/21/2021 4:00:00 PM  Lia            NaN   99    NaN
# 2/21/2021 21:06:59 2/21/2021 8:30:00 AM  Ram        Tylenol  NaN    NaN
# 2/21/2021 21:07:29 2/21/2021 4:00:00 PM  Ram        Tylenol  NaN    NaN
# 2/21/2021 21:08:03 2/21/2021 4:00:00 PM  Ram     Robitussin  NaN    NaN
# 2/21/2021 21:08:47 2/21/2021 5:00:00 PM  Sri     Robitussin  NaN    NaN
# 2/21/2021 21:21:31 2/21/2021 8:20:00 PM  Ram            NaN  NaN   99.2
# 2/21/2021 21:22:42 2/21/2021 8:20:00 PM  Ram            NaN   98    NaN
# 2/22/2021 12:33:09 2/22/2021 2:30:00 AM  Krithi     Tylenol  NaN    NaN
# 2/22/2021 12:33:31 2/22/2021 11:30:00 AM Ram            NaN   97    NaN
# 2/22/2021 3:18:30  2/22/2021 2:15:00 AM  Ram            NaN  NaN  100.1
# 2/22/2021 3:18:57  2/22/2021 2:15:00 AM  Ram            NaN   94    NaN
# 2/22/2021 3:28:56  2/22/2021 2:30:00 AM  Krithi         NaN  NaN   99.4
# 2/22/2021 3:29:30  2/22/2021 2:30:00 AM  Krithi     Tylenol  NaN    NaN

# %%
# merging DF on common colounms
dfa = pd.DataFrame({'A1': ['a','b','c'],
                   'A2' : [1,2,3]})

dfb = pd.DataFrame({'A1': ['b','c','d','e'],
                   'B2' : [100,200,300,400]})

print("-- dfa --")
display(dfa)

print ('-- dfb --')
display(dfb)

print ('-- merge (default: inner) --')
display(dfa.merge(dfb))

print ('-- merge left -- ')
display(dfa.merge(dfb,how='left',on='A1'))
                  
print ('-- merge right --')
display(dfa.merge(dfb,how='right',on='A1'))

print ('-- merge inner ---')                 
display(dfa.merge(dfb,how='inner',on='A1'))

print ('-- merge outer ---')                 
display(dfa.merge(dfb,how='outer',on='A1'))
# Out:
# -- dfa --
#   A1  A2
# 0  a   1
# 1  b   2
# 2  c   3
# -- dfb --
#   A1   B2
# 0  b  100
# 1  c  200
# 2  d  300
# 3  e  400
# -- merge (default: inner) --
#   A1  A2   B2
# 0  b   2  100
# 1  c   3  200
# -- merge left --
#   A1  A2     B2
# 0  a   1    NaN
# 1  b   2  100.0
# 2  c   3  200.0
# -- merge right --
#   A1   A2   B2
# 0  b  2.0  100
# 1  c  3.0  200
# 2  d  NaN  300
# 3  e  NaN  400
# -- merge inner ---
#   A1  A2   B2
# 0  b   2  100
# 1  c   3  200
# -- merge outer ---
#   A1   A2     B2
# 0  a  1.0    NaN
# 1  b  2.0  100.0
# 2  c  3.0  200.0
# 3  d  NaN  300.0
# 4  e  NaN  400.0

# %%
dfa = pd.DataFrame({'A1': ['a','b'],
                   'A2' : [1,2]})

dfb = pd.DataFrame({'B1': ['b','c'],
                    'B2' : [100,200]})

dfa.merge(dfb, left_on='A1', right_on='B1', how='outer')
# Out:
#     A1   A2   B1     B2
# 0    a  1.0  NaN    NaN
# 1    b  2.0    b  100.0
# 2  NaN  NaN    c  200.0

# %%
dfa = pd.DataFrame({'A1': ['a','b','c'],
                   'A2' : [1,2,3]})

dfb = pd.DataFrame({ 'A1': ['a','c','b'],
                    'A2' : [1,3,2]})

dfb_s = canonicalize (dfb)

display(dfa, dfb, dfb_s)
print(v)
dfa.equals(dfb)
# Out:
#   A1  A2
# 0  a   1
# 1  b   2
# 2  c   3
#   A1  A2
# 0  a   1
# 1  c   3
# 2  b   2
#   A1  A2
# 0  a   1
# 1  b   2
# 2  c   3
# ['A1', 'A2']
# False

# %%
# melting DF - make wide -> narrow
df_w = pd.DataFrame({'A1': ['a','b','c'],
                   'V2' : [1,2,3],
                   'V3' : [11,22,33],
                   'V4': [21,22,23]})

c = df_w.columns
cl = list(c)
v = ['V2','V3','V4']
[ cl.remove(x) for x in v ] 
print (f' columns: {c}\n id_vars: {cl}\n value_vars: {v}')

df_n = df_w.melt(id_vars=cl,
                value_vars = v,
                var_name='VAR',
                value_name='VAL')

display(df_w, df_n)
# Out:
#  columns: Index(['A1', 'V2', 'V3', 'V4'], dtype='object')
#  id_vars: ['A1']
#  value_vars: ['V2', 'V3', 'V4']
#   A1  V2  V3  V4
# 0  a   1  11  21
# 1  b   2  22  22
# 2  c   3  33  23
#   A1 VAR  VAL
# 0  a  V2    1
# 1  b  V2    2
# 2  c  V2    3
# 3  a  V3   11
# 4  b  V3   22
# 5  c  V3   33
# 6  a  V4   21
# 7  b  V4   22
# 8  c  V4   23

# %%
#from 
#https://www.youtube.com/watch?v=kJsiiPK5sxs
#https://github.com/knathanieltucker/pandas-tutorial/blob/master/notebooks/Row-Column%20Transformations.ipynb
    
tips = sns.load_dataset('tips')
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
tips_gb = tips.groupby(['day', 'sex']).agg({'size' : 'sum'})
tips_gb
# Out:
#              size
# day  sex
# Thur Male      73
#      Female    79
# Fri  Male      21
#      Female    19
# Sat  Male     156
#      Female    63
# Sun  Male     163
#      Female    53

# %%
#tibs_gb2 = tips_gb.pivot(columns=['sex'], values='size')
#tips_gb2
tips_gb1 = tips_gb.unstack()
tips_gb1
#tips_gb1['size', 'Male'] <-- access multi index col.
# Out:
# day
# Thur     73
# Fri      21
# Sat     156
# Sun     163
# Name: (size, Male), dtype: int64

# %%
# flatten multi index col names 
tips_gb1.columns = ['__'.join(col).strip() for col in tips_gb1.columns.values]
tips_gb1
# Out:
#       size__Male  size__Female
# day
# Thur          73            79
# Fri           21            19
# Sat          156            63
# Sun          163            53

# %%
tips_gb1['mf_ratio'] = tips_gb1.size__Male / tips_gb1.size__Female
tips_gb1
# Out:
#       size__Male  size__Female  mf_ratio
# day
# Thur          73            79  0.924051
# Fri           21            19  1.105263
# Sat          156            63  2.476190
# Sun          163            53  3.075472

# %%
tips_gb2 = tips_gb.unstack(0)
tips_gb2
# Out:
#        size
# day    Thur Fri  Sat  Sun
# sex
# Male     73  21  156  163
# Female   79  19   63   53

# %%
tips_gb2.columns = ['__'.join(col).strip() for col in tips_gb2.columns.values]
tips_gb2
# Out:
#         size__Thur  size__Fri  size__Sat  size__Sun
# sex
# Male            73         21        156        163
# Female          79         19         63         53

# %%
df1 = pd.DataFrame({'first': ['John', 'Mary'],
                        'last': ['Doe', 'Bo'],
                        'height': [5.5, 6.0],
                        'weight': [130, 150]})
df1
# Out:
#   first last  height  weight
# 0  John  Doe     5.5     130
# 1  Mary   Bo     6.0     150

# %%
# melting can be done with stacking
df1.melt(id_vars=['first', 'last'])
# Out:
#   first last variable  value
# 0  John  Doe   height    5.5
# 1  Mary   Bo   height    6.0
# 2  John  Doe   weight  130.0
# 3  Mary   Bo   weight  150.0

# %%
#samething with stack
df1.set_index(['first', 'last'], inplace=True)
df1.stack().reset_index()
# Out:
#   first last level_2      0
# 0  John  Doe  height    5.5
# 1  John  Doe  weight  130.0
# 2  Mary   Bo  height    6.0
# 3  Mary   Bo  weight  150.0

# %%
def filterdata(data, low, high):
    ###
    ### YOUR CODE HERE
    ###
    df = pd.DataFrame(data, columns=['price', 'city'])
    # multiple conditions. (condition1) & (condition)
    df1 = df[(df['price'] >= low) & (df['price'] <= high)]
    
    # convert df to list
    o = df1.values.tolist()
    print (f'ret {len(o)} results')
    
    #print (o[0:10])
    #print('values', df1.values.tolist())
    return (o)

# %%
    print (f'tally_gaps got {len(votes_gap)} entries')
    #pp.pprint(votes_gap[0:2])
    df = pd.DataFrame(votes_gap)
    r = re.compile('(\d{4})-(\d{2})-(\d{2})')

    df['year'] = df.apply( lambda x : r.match(x['date']).group(1), axis = 1 )
    df1 = df[['gap', 'year']]
    df1['year'] = df1['year'].astype(int)
    df1 = df1.groupby(by=["year"], dropna=False).mean()
    df1 = df1.reset_index().values

    display(df1.head(3))

    o = df1.reset_index().values
    print(f'out {o}')
    return o
